# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import hvplot.pandas

# %%
# Read in the CSV file as a Pandas DataFrame
data_df = pd.read_csv(
    Path("data/Most-Recent-Cohorts-Institution.csv")
)

# Review the DataFrame
data_df.head(3)
# Out:
# C:\Users\KSPow\AppData\Local\Temp\ipykernel_5816\4101174598.py:2: DtypeWarning: Columns (9,1537,1540,1542,1606,1608,1614,1615,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1703,1704,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2376,2377,2403,2404,2495,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,2958) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv(
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# ...

# %%
#select columns to keeps
desired_columns = ['UNITID', 'STABBR', 'HIGHDEG','CONTROL', 'COSTT4_A', 'TUITIONFEE_IN', 'TUITIONFEE_OUT', 'GRAD_DEBT_MDN10YR', 'GRAD_DEBT_MDN_SUPP', 'NPT4_PUB', 'MN_EARN_WNE_P10', 'MN_EARN_WNE_P6', 'MN_EARN_WNE_P7', 'MN_EARN_WNE_P8', 'MN_EARN_WNE_P9'   
                ]
only_cols = data_df.loc[:, desired_columns]


#data_df[desired_columns] = data_df[desired_columns].replace('PrivacySuppressed', 'NaN')
only_cols.head(50)
# Out:
#     UNITID STABBR  HIGHDEG  CONTROL  COSTT4_A  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 0   100654     AL        4        1   21924.0        10024.0         18634.0
# 1   100663     AL        4        1   26248.0         8568.0         20400.0
# 2   100690     AL        4        2       NaN            NaN             NaN
# 3   100706     AL        4        1   24869.0        11488.0         23884.0
# 4   100724     AL        4        1   21938.0        11068.0         19396.0
# 5   100751     AL        4        1   31050.0        11620.0         31090.0
# 6   100760     AL        2        1   13930.0         4930.0          8620.0
# 7   100812     AL        4        1       NaN            NaN             NaN
# 8   100830     AL        4        1   20621.0         8860.0         18820.0
# 9   100858     AL        4        1   32678.0        11826.0         31986.0
# 10  100937     AL        3        2   33920.0        20100.0         20100.0
# ...

# %%
column_names = ['UNITID','STABBR', 'HIGHDEG','CONTROL', 'COSTT4_A', 'TUITIONFEE_IN', 'TUITIONFEE_OUT', 'GRAD_DEBT_MDN10YR', 'GRAD_DEBT_MDN_SUPP', 'NPT4_PUB', 'MN_EARN_WNE_P10', 'MN_EARN_WNE_P6', 'MN_EARN_WNE_P7', 'MN_EARN_WNE_P8', 'MN_EARN_WNE_P9' ]
cleaned_df = only_cols.dropna(subset= column_names)
cleaned_df.head(50)
# Out:
#     UNITID STABBR  HIGHDEG  CONTROL  COSTT4_A  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 0   100654     AL        4        1   21924.0        10024.0         18634.0
# 1   100663     AL        4        1   26248.0         8568.0         20400.0
# 3   100706     AL        4        1   24869.0        11488.0         23884.0
# 4   100724     AL        4        1   21938.0        11068.0         19396.0
# 5   100751     AL        4        1   31050.0        11620.0         31090.0
# 6   100760     AL        2        1   13930.0         4930.0          8620.0
# 8   100830     AL        4        1   20621.0         8860.0         18820.0
# 9   100858     AL        4        1   32678.0        11826.0         31986.0
# 11  101028     AL        2        1    9320.0         3936.0          7128.0
# 13  101143     AL        2        1    9454.0         4860.0          8550.0
# 14  101161     AL        2        1   12881.0         4860.0          8850.0
# ...

# %%
cleaned_df = cleaned_df[(cleaned_df['GRAD_DEBT_MDN10YR'] != 'PrivacySuppressed') & 
                    (cleaned_df['GRAD_DEBT_MDN_SUPP'] != 'PrivacySuppressed') & 
                    (cleaned_df['MN_EARN_WNE_P10'] != 'PrivacySuppressed') & 
                    (cleaned_df['MN_EARN_WNE_P6'] != 'PrivacySuppressed') & 
                    (cleaned_df['MN_EARN_WNE_P7'] != 'PrivacySuppressed') & 
                    (cleaned_df['MN_EARN_WNE_P8'] != 'PrivacySuppressed') & 
                    (cleaned_df['MN_EARN_WNE_P9'] != 'PrivacySuppressed')]
cleaned_df.head()
# Out:
#    UNITID STABBR  HIGHDEG  CONTROL  COSTT4_A  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 0  100654     AL        4        1   21924.0        10024.0         18634.0
# 1  100663     AL        4        1   26248.0         8568.0         20400.0
# 3  100706     AL        4        1   24869.0        11488.0         23884.0
# 4  100724     AL        4        1   21938.0        11068.0         19396.0
# 5  100751     AL        4        1   31050.0        11620.0         31090.0
#
#   GRAD_DEBT_MDN10YR GRAD_DEBT_MDN_SUPP  NPT4_PUB MN_EARN_WNE_P10  \
# 0  328.651592227982              31000   13057.0           35500
# 1  236.417113118838              22300   16585.0           48400
# 3  219.507458615495              20705   17250.0           52000
# 4  328.651592227982              31000   13593.0           30600
# 5  241.187862038277              22750   21534.0           51600
#
#   MN_EARN_WNE_P6 MN_EARN_WNE_P7 MN_EARN_WNE_P8 MN_EARN_WNE_P9
# ...

# %%
#change data type from object to float
cleaned_df = cleaned_df.astype({"COSTT4_A":"int","TUITIONFEE_IN":"int", "TUITIONFEE_OUT":"int","GRAD_DEBT_MDN10YR":"float","GRAD_DEBT_MDN_SUPP":"int","NPT4_PUB":"int", "MN_EARN_WNE_P10":"int", "MN_EARN_WNE_P6":"int",
                        "MN_EARN_WNE_P7":"int", "MN_EARN_WNE_P8":"int", "MN_EARN_WNE_P9":"int"})
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 0 to 5978
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UNITID              1296 non-null   int64
#  1   STABBR              1296 non-null   object
#  2   HIGHDEG             1296 non-null   int64
#  3   CONTROL             1296 non-null   int64
#  4   COSTT4_A            1296 non-null   int32
#  5   TUITIONFEE_IN       1296 non-null   int32
#  6   TUITIONFEE_OUT      1296 non-null   int32
#  7   GRAD_DEBT_MDN10YR   1296 non-null   float64
#  8   GRAD_DEBT_MDN_SUPP  1296 non-null   int32
#  9   NPT4_PUB            1296 non-null   int32
#  10  MN_EARN_WNE_P10     1296 non-null   int32
#  11  MN_EARN_WNE_P6      1296 non-null   int32
#  12  MN_EARN_WNE_P7      1296 non-null   int32
#  13  MN_EARN_WNE_P8      1296 non-null   int32
#  14  MN_EARN_WNE_P9      1296 non-null   int32
# ...

# %%
len(cleaned_df)
# Out:
# 1296

# %%
cleaned_df.head(30)
# Out:
#     UNITID STABBR  HIGHDEG  CONTROL  COSTT4_A  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 0   100654     AL        4        1     21924          10024           18634
# 1   100663     AL        4        1     26248           8568           20400
# 3   100706     AL        4        1     24869          11488           23884
# 4   100724     AL        4        1     21938          11068           19396
# 5   100751     AL        4        1     31050          11620           31090
# 6   100760     AL        2        1     13930           4930            8620
# 8   100830     AL        4        1     20621           8860           18820
# 9   100858     AL        4        1     32678          11826           31986
# 11  101028     AL        2        1      9320           3936            7128
# 13  101143     AL        2        1      9454           4860            8550
# 14  101161     AL        2        1     12881           4860            8850
# ...

# %%
cleaned_df.to_csv("data/Clean_Most-Recent-Cohorts-Institution.csv")

# %%
data_df = pd.read_csv(
    Path("data/Most-Recent-Cohorts-Field-of-Study.csv")
)

# Review the DataFrame
data_df.head(20)
# Out:
#       UNITID  OPEID6                    INSTNM CONTROL  MAIN  CIPCODE  \
# 0   100654.0    1002  Alabama A & M University  Public     1      100
# 1   100654.0    1002  Alabama A & M University  Public     1      101
# 2   100654.0    1002  Alabama A & M University  Public     1      109
# 3   100654.0    1002  Alabama A & M University  Public     1      110
# 4   100654.0    1002  Alabama A & M University  Public     1      110
# 5   100654.0    1002  Alabama A & M University  Public     1      110
# 6   100654.0    1002  Alabama A & M University  Public     1      111
# 7   100654.0    1002  Alabama A & M University  Public     1      199
# 8   100654.0    1002  Alabama A & M University  Public     1      199
# 9   100654.0    1002  Alabama A & M University  Public     1      199
# 10  100654.0    1002  Alabama A & M University  Public     1      305
# 11  100654.0    1002  Alabama A & M University  Public     1      403
# ...

# %%
#select columns to keep

study_columns= ['UNITID', 'INSTNM', 'CIPCODE', 'CREDLEV', 'CIPDESC','DEBT_ALL_STGP_ANY_MEAN', 'DEBT_ALL_PP_ANY_MEAN','DEBT_ALL_PP_EVAL_MEAN','DEBT_ALL_STGP_EVAL_MEAN', 'DEBT_ALL_PP_ANY_MDN10YRPAY', 'DEBT_ALL_PP_EVAL_MDN10YRPAY', 
               'EARN_MDN_HI_1YR', 'EARN_MDN_HI_2YR', 'EARN_NE_MDN_3YR', 'EARN_MDN_4YR']
these_cols = data_df.loc[:, study_columns]


these_cols.head(50)
# Out:
#       UNITID                    INSTNM  CIPCODE  CREDLEV  \
# 0   100654.0  Alabama A & M University      100        3
# 1   100654.0  Alabama A & M University      101        3
# 2   100654.0  Alabama A & M University      109        3
# 3   100654.0  Alabama A & M University      110        3
# 4   100654.0  Alabama A & M University      110        5
# 5   100654.0  Alabama A & M University      110        6
# 6   100654.0  Alabama A & M University      111        3
# 7   100654.0  Alabama A & M University      199        3
# 8   100654.0  Alabama A & M University      199        5
# 9   100654.0  Alabama A & M University      199        6
# 10  100654.0  Alabama A & M University      305        3
# 11  100654.0  Alabama A & M University      403        3
# 12  100654.0  Alabama A & M University      403        5
# 13  100654.0  Alabama A & M University      502        3
# 14  100654.0  Alabama A & M University      901        5
# ...

# %%
#drop NA values
column_nms = ['UNITID', 'CIPCODE', 'CREDLEV', 'DEBT_ALL_STGP_ANY_MEAN', 'DEBT_ALL_PP_ANY_MEAN','DEBT_ALL_PP_EVAL_MEAN','DEBT_ALL_STGP_EVAL_MEAN', 'DEBT_ALL_PP_ANY_MDN10YRPAY', 'DEBT_ALL_PP_EVAL_MDN10YRPAY', 
               'EARN_MDN_HI_1YR', 'EARN_MDN_HI_2YR', 'EARN_NE_MDN_3YR', 'EARN_MDN_4YR']

# Initialize the DataFrame 'cleaned_df' as a copy of 'only_cols'
clean_df = these_cols.copy()

# Iterate through the specified columns and drop rows with NaN values in each column
for col in column_nms:
    clean_df = clean_df[clean_df[col].notnull()]

clean_df.head()
# Out:
#      UNITID                    INSTNM  CIPCODE  CREDLEV  \
# 0  100654.0  Alabama A & M University      100        3
# 2  100654.0  Alabama A & M University      109        3
# 3  100654.0  Alabama A & M University      110        3
# 4  100654.0  Alabama A & M University      110        5
# 5  100654.0  Alabama A & M University      110        6
#
#                         CIPDESC DEBT_ALL_STGP_ANY_MEAN DEBT_ALL_PP_ANY_MEAN  \
# 0         Agriculture, General.      PrivacySuppressed    PrivacySuppressed
# 2              Animal Sciences.      PrivacySuppressed    PrivacySuppressed
# 3  Food Science and Technology.      PrivacySuppressed    PrivacySuppressed
# 4  Food Science and Technology.      PrivacySuppressed    PrivacySuppressed
# 5  Food Science and Technology.      PrivacySuppressed    PrivacySuppressed
#
#   DEBT_ALL_PP_EVAL_MEAN DEBT_ALL_STGP_EVAL_MEAN DEBT_ALL_PP_ANY_MDN10YRPAY  \
# 0     PrivacySuppressed       PrivacySuppressed          PrivacySuppressed
# ...

# %%
clean_df = clean_df[(clean_df['DEBT_ALL_STGP_ANY_MEAN'] != 'PrivacySuppressed') & 
                    (clean_df['DEBT_ALL_PP_ANY_MEAN'] != 'PrivacySuppressed') & 
                    (clean_df['DEBT_ALL_PP_EVAL_MEAN'] != 'PrivacySuppressed') & 
                    (clean_df['DEBT_ALL_STGP_EVAL_MEAN'] != 'PrivacySuppressed') & 
                    (clean_df['DEBT_ALL_PP_ANY_MDN10YRPAY'] != 'PrivacySuppressed') & 
                    (clean_df['DEBT_ALL_PP_EVAL_MDN10YRPAY'] != 'PrivacySuppressed') & 
                    (clean_df['EARN_MDN_HI_1YR'] != 'PrivacySuppressed') & 
                    (clean_df['EARN_MDN_HI_2YR'] != 'PrivacySuppressed') & 
                    (clean_df['EARN_NE_MDN_3YR'] != 'PrivacySuppressed')& 
                    (clean_df['EARN_MDN_4YR'] != 'PrivacySuppressed')]
clean_df.head()
# Out:
#        UNITID                               INSTNM  CIPCODE  CREDLEV  \
# 66   100663.0  University of Alabama at Birmingham      901        3
# 89   100663.0  University of Alabama at Birmingham     1313        3
# 120  100663.0  University of Alabama at Birmingham     2601        3
# 163  100663.0  University of Alabama at Birmingham     4201        3
# 191  100663.0  University of Alabama at Birmingham     5107        3
#
#                                                CIPDESC DEBT_ALL_STGP_ANY_MEAN  \
# 66                    Communication and Media Studies.                  26312
# 89   Teacher Education and Professional Development...                  24668
# 120                                  Biology, General.                  23301
# 163                               Psychology, General.                  27457
# 191        Health and Medical Administrative Services.                  30157
#
#     DEBT_ALL_PP_ANY_MEAN DEBT_ALL_PP_EVAL_MEAN DEBT_ALL_STGP_EVAL_MEAN  \
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6445 entries, 66 to 222277
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UNITID                       6445 non-null   float64
#  1   INSTNM                       6445 non-null   object
#  2   CIPCODE                      6445 non-null   int64
#  3   CREDLEV                      6445 non-null   int64
#  4   CIPDESC                      6445 non-null   object
#  5   DEBT_ALL_STGP_ANY_MEAN       6445 non-null   object
#  6   DEBT_ALL_PP_ANY_MEAN         6445 non-null   object
#  7   DEBT_ALL_PP_EVAL_MEAN        6445 non-null   object
#  8   DEBT_ALL_STGP_EVAL_MEAN      6445 non-null   object
#  9   DEBT_ALL_PP_ANY_MDN10YRPAY   6445 non-null   object
#  10  DEBT_ALL_PP_EVAL_MDN10YRPAY  6445 non-null   object
#  11  EARN_MDN_HI_1YR              6445 non-null   object
#  12  EARN_MDN_HI_2YR              6445 non-null   object
# ...

# %%
clean_df = clean_df.astype({"UNITID":"int", "DEBT_ALL_STGP_ANY_MEAN":"int","DEBT_ALL_PP_ANY_MEAN":"float", "DEBT_ALL_PP_EVAL_MEAN":"float", "DEBT_ALL_STGP_EVAL_MEAN":"float",
                        "DEBT_ALL_PP_ANY_MDN10YRPAY":"float", "DEBT_ALL_PP_EVAL_MDN10YRPAY":"float", "EARN_MDN_HI_1YR":"float", "EARN_MDN_HI_2YR":"float", "EARN_NE_MDN_3YR":"float", "EARN_MDN_4YR":"float"})

# %%
clean_df.nunique()
# Out:
# UNITID                         1761
# INSTNM                         1735
# CIPCODE                         192
# CREDLEV                           3
# CIPDESC                         192
# DEBT_ALL_STGP_ANY_MEAN         3908
# DEBT_ALL_PP_ANY_MEAN           4245
# DEBT_ALL_PP_EVAL_MEAN          4246
# DEBT_ALL_STGP_EVAL_MEAN        3803
# DEBT_ALL_PP_ANY_MDN10YRPAY      779
# DEBT_ALL_PP_EVAL_MDN10YRPAY     804
# EARN_MDN_HI_1YR                4172
# EARN_MDN_HI_2YR                2605
# EARN_NE_MDN_3YR                4205
# EARN_MDN_4YR                   4241
# dtype: int64

# %%
# list of values of 'CREDLEV' column
clean_df.CREDLEV.unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6445 entries, 66 to 222277
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UNITID                       6445 non-null   int32
#  1   INSTNM                       6445 non-null   object
#  2   CIPCODE                      6445 non-null   int64
#  3   CREDLEV                      6445 non-null   int64
#  4   CIPDESC                      6445 non-null   object
#  5   DEBT_ALL_STGP_ANY_MEAN       6445 non-null   int32
#  6   DEBT_ALL_PP_ANY_MEAN         6445 non-null   float64
#  7   DEBT_ALL_PP_EVAL_MEAN        6445 non-null   float64
#  8   DEBT_ALL_STGP_EVAL_MEAN      6445 non-null   float64
#  9   DEBT_ALL_PP_ANY_MDN10YRPAY   6445 non-null   float64
#  10  DEBT_ALL_PP_EVAL_MDN10YRPAY  6445 non-null   float64
#  11  EARN_MDN_HI_1YR              6445 non-null   float64
# ...

# %%
len(clean_df)
# Out:
# 6445

# %%
clean_df.head(30)
# Out:
#      UNITID                               INSTNM  CIPCODE  CREDLEV  \
# 66   100663  University of Alabama at Birmingham      901        3
# 89   100663  University of Alabama at Birmingham     1313        3
# 120  100663  University of Alabama at Birmingham     2601        3
# 163  100663  University of Alabama at Birmingham     4201        3
# 191  100663  University of Alabama at Birmingham     5107        3
# 203  100663  University of Alabama at Birmingham     5122        3
# 213  100663  University of Alabama at Birmingham     5138        3
# 218  100663  University of Alabama at Birmingham     5202        3
# 353  100706  University of Alabama in Huntsville     5138        3
# 400  100724             Alabama State University     1312        3
# 428  100724             Alabama State University     5123        3
# 452  100751            The University of Alabama      909        3
# 475  100751            The University of Alabama     1313        3
# ...

# %%
clean_df.to_csv("data/clean_Most-Recent-Cohorts-Field-of-Study.csv")
